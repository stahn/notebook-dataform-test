# %%
# ==============================================================================
# OSTATECZNY KOD DLA NOTATNIKA: test-repo-notebook.ipynb
# ==============================================================================

import os
import sys

# --- KROK 1: Klonowanie Twojego publicznego repozytorium z GitHub ---
# Ta komórka pobierze wszystkie pliki z Twojego repozytorium do środowiska,
# w którym działa ten notatnik.

repo_url = 'https://github.com/stahn/notebook-dataform-test'
repo_name = 'notebook-dataform-test' # Nazwa folderu, który zostanie utworzony

# Sklonuj repozytorium tylko wtedy, gdy folder jeszcze nie istnieje
if not os.path.exists(repo_name):
    print(f"Klonowanie repozytorium '{repo_name}'...")
    # !git clone {repo_url}
else:
    print(f"Repozytorium '{repo_name}' już istnieje. Pomijam klonowanie.")

# Wyświetl zawartość sklonowanego folderu, aby potwierdzić, że pliki tam są
print(f"\nZawartość folderu '{repo_name}':")
# !ls -l {repo_name}


# --- KROK 2: Dodanie ścieżki do modułów Pythona ---
# Informujemy Pythona, aby szukał modułów (plików .py) wewnątrz
# sklonowanego katalogu.

project_root = f'/content/{repo_name}/modules'
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"\nDodano '{project_root}' do ścieżki Pythona.")


# --- KROK 3: Import i użycie funkcji z modułu `my_module.py` ---
# Teraz, gdy Python wie, gdzie szukać, możemy swobodnie importować
# i używać kodu z innych plików .py w repozytorium.

from my_module import append_random_record_to_bq

# Zmienne specyficzne dla Twojego projektu w Google Cloud
project = 'lexmotion-analytics'
table = 'test_repo.notebook_output'

print(f"\nUruchamiam funkcję z modułu, aby dodać rekord do tabeli: {project}:{table}")
appended_df = append_random_record_to_bq(table, project)

# Wyświetl DataFrame, który został dodany, jako potwierdzenie
appended_df
# Out:
# Repozytorium 'notebook-dataform-test' już istnieje. Pomijam klonowanie.
#
# Zawartość folderu 'notebook-dataform-test':
# total 28
# drwxr-xr-x 2 root root  4096 Jun 10 05:01 definitions
# drwxr-xr-x 3 root root  4096 Jun 10 05:02 modules
# -rw-r--r-- 1 root root 12923 Jun 10 05:01 test-repo-notebook.ipynb
# -rw-r--r-- 1 root root   153 Jun 10 05:01 workflow_settings.yaml
#
# Uruchamiam funkcję z modułu, aby dodać rekord do tabeli: lexmotion-analytics:test_repo.notebook_output
# 100%|██████████| 1/1 [00:00<00:00, 7269.16it/s]
# Pomyślnie dodano rekord do tabeli: test_repo.notebook_output
#                         time      output
# 0 2025-06-10 05:03:25.263625  0mrvg8f9l6

# %%
from my_module import append_random_record_to_bq

# Zmienne specyficzne dla Twojego projektu w Google Cloud
project = 'lexmotion-analytics'
table = 'test_repo.notebook_output'

print(f"\nUruchamiam funkcję z modułu, aby dodać rekord do tabeli: {project}:{table}")
appended_df = append_random_record_to_bq(table, project)

# Wyświetl DataFrame, który został dodany, jako potwierdzenie
appended_df
# Out:
# Uruchamiam funkcję z modułu, aby dodać rekord do tabeli: lexmotion-analytics:test_repo.notebook_output
# 100%|██████████| 1/1 [00:00<00:00, 8648.05it/s]
# Pomyślnie dodano rekord do tabeli: test_repo.notebook_output
#                         time      output
# 0 2025-06-10 05:04:04.768304  4jbmbczjdy

# %%
# prompt: display all files in the local directory

import os

for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# prompt: append to table `lexmotion-analytics.test_repo.notebook_output` a row with the current timestamp and a random string. the schema of the table is as follow:
#d

import pandas_gbq
import pandas as pd
from datetime import datetime
import random
import string

# Generate random string
random_string = ''.join(random.choices(string.ascii_lowercase + string.digits, k=10))

# Create a DataFrame with the new data
df_new = pd.DataFrame({'time': [datetime.now()], 'output': [random_string]})

# # Append the DataFrame to the BigQuery table
# pandas_gbq.to_gbq(df_new, 'lexmotion-analytics.test_repo.notebook_output', project_id='lexmotion-analytics', if_exists='append')

# %%
df_new
# Out:
#                         time      output
# 0 2025-06-08 16:23:52.240808  kmd905vk4f

# %%
# Append the DataFrame to the BigQuery table
pandas_gbq.to_gbq(df_new, 'lexmotion-analytics.test_repo.notebook_output', project_id='lexmotion-analytics', if_exists='append')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 8050.49it/s]
